# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv('dataset/covid.csv')

# %%
a
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10741       0       10612
# 1                             Andhra Pradesh      2339048       9     2324306
# 2                          Arunachal Pradesh        66887       1       66590
# 3                                      Assam       746099       0      738064
# 4                                      Bihar       851339      18      839019
# 5                                 Chandigarh        99335       7       98147
# 6                               Chhattisgarh      1177724      14     1163565
# 7   Dadra and Nagar Haveli and Daman and Diu        11591       1       11586
# 8                                      Delhi      2006921      25     1980379
# 9                                        Goa       259016      44      254959
# 10                                   Gujarat      1277422     221     1266158
# ...

# %% [markdown]
# #  Column name change

# %%
a=a.rename(columns={'State/UTs':'State'})

# %% [markdown]
# # Show all columns name

# %%
a.columns
# Out:
# Index(['State', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio', 'Discharge Ratio', 'Death Ratio', 'Population'],
#       dtype='object')

# %% [markdown]
# # show numbers of rows and columns

# %%
a.shape
# Out:
# (36, 9)

# %% [markdown]
# # highest deaths row

# %%
a[a.Deaths==a.Deaths.max()]
# Out:
#           State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 20  Maharashtra      8135620     504     7986710  148406          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 20            98.17         1.82      399001

# %% [markdown]
# # highest Active case

# %%
a[a.Active==a.Active.max()]
# Out:
#      State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 16  Kerala      6825913    1765     6752658   71490          0.03
#
#     Discharge Ratio  Death Ratio  Population
# 16            98.93         1.05    91702478

# %% [markdown]
# # show only state records

# %%
a.loc[:,'State']
# Out:
# 0                          Andaman and Nicobar
# 1                               Andhra Pradesh
# 2                            Arunachal Pradesh
# 3                                        Assam
# 4                                        Bihar
# 5                                   Chandigarh
# 6                                 Chhattisgarh
# 7     Dadra and Nagar Haveli and Daman and Diu
# 8                                        Delhi
# 9                                          Goa
# 10                                     Gujarat
# 11                                     Haryana
# 12                            Himachal Pradesh
# 13                           Jammu and Kashmir
# 14                                   Jharkhand
# 15                                   Karnataka
# 16                                      Kerala
# 17                                      Ladakh
# 18                                 Lakshadweep
# 19                              Madhya Pradesh
# ...

# %% [markdown]
# # how to find all missing value count in all columns

# %%
a.isnull().sum()
# Out:
# State              0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# Population         0
# dtype: int64

# %% [markdown]
# # show top 3 minimum active complete records

# %%
df=a.sort_values(by='Active').index[:3]

# %%
df
# Out:
# Int64Index([0, 3, 24], dtype='int64')

# %%
a.iloc[df,[2]]
# Out:
#     Active
# 0        0
# 3        0
# 24       0

# %% [markdown]
# # show all active totals

# %%
a.Active.sum()
# Out:
# 5263

# %% [markdown]
# # State wise active records

# %%
 a.loc[:,['State','Active']]
# Out:
#                                        State  Active
# 0                        Andaman and Nicobar       0
# 1                             Andhra Pradesh       9
# 2                          Arunachal Pradesh       1
# 3                                      Assam       0
# 4                                      Bihar      18
# 5                                 Chandigarh       7
# 6                               Chhattisgarh      14
# 7   Dadra and Nagar Haveli and Daman and Diu       1
# 8                                      Delhi      25
# 9                                        Goa      44
# 10                                   Gujarat     221
# 11                                   Haryana      50
# 12                          Himachal Pradesh      28
# 13                         Jammu and Kashmir      19
# 14                                 Jharkhand      18
# 15                                 Karnataka    1618
# 16                                    Kerala    1765
# ...

# %% [markdown]
# # greater than 100 deaths State shows

# %%
a[a.Deaths>100].State
# Out:
# 0     Andaman and Nicobar
# 1          Andhra Pradesh
# 2       Arunachal Pradesh
# 3                   Assam
# 4                   Bihar
# 5              Chandigarh
# 6            Chhattisgarh
# 8                   Delhi
# 9                     Goa
# 10                Gujarat
# 11                Haryana
# 12       Himachal Pradesh
# 13      Jammu and Kashmir
# 14              Jharkhand
# 15              Karnataka
# 16                 Kerala
# 17                 Ladakh
# 19         Madhya Pradesh
# 20            Maharashtra
# 21                Manipur
# 22              Meghalaya
# 23                Mizoram
# 24               Nagaland
# 25                 Odisha
# 26             Puducherry
# 27                 Punjab
# 28              Rajasthan
# 29                 Sikkim
# 30             Tamil Nadu
# 31              Telengana
# 32                Tripura
# 33          Uttar Pradesh
# 34            Uttarakhand
# 35            West Bengal
# Name: State, dtype: object

# %% [markdown]
# #  Only Starting 2 rows

# %%
a.loc[[0,1]]
# Out:
#                  State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10741       0       10612     129           0.0
# 1       Andhra Pradesh      2339048       9     2324306   14733           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364

# %% [markdown]
# # only 1 active

# %%
a[a.Active==1]
# Out:
#                                        State  Total Cases  Active  Discharged  \
# 2                          Arunachal Pradesh        66887       1       66590
# 7   Dadra and Nagar Haveli and Daman and Diu        11591       1       11586
# 32                                   Tripura       108032       1      107091
#
#     Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# 2      296          0.00            99.56         0.44      658019
# 7        4          0.01            99.96         0.03   231502578
# 32     940          0.00            99.13         0.87     1646050

# %% [markdown]
# # State wise all records

# %%
b=a.groupby('State')
for State,data in b:
    print("State",State)
    print("\n")
    print("Report",data)
# Out:
# State Andaman and Nicobar
#
#
# Report                  State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10741       0       10612     129           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0             98.8          1.2   100896618
# State Andhra Pradesh
#
#
# Report             State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 1  Andhra Pradesh      2339048       9     2324306   14733           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 1            99.37         0.63   128500364
# State Arunachal Pradesh
#
#
# Report                State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 2  Arunachal Pradesh        66887       1       66590     296           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 2            99.56         0.44      658019
# State Assam
#
#
# Report    State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# ...

# %%
a.head(10)
# Out:
#                                       State  Total Cases  Active  Discharged  \
# 0                       Andaman and Nicobar        10741       0       10612
# 1                            Andhra Pradesh      2339048       9     2324306
# 2                         Arunachal Pradesh        66887       1       66590
# 3                                     Assam       746099       0      738064
# 4                                     Bihar       851339      18      839019
# 5                                Chandigarh        99335       7       98147
# 6                              Chhattisgarh      1177724      14     1163565
# 7  Dadra and Nagar Haveli and Daman and Diu        11591       1       11586
# 8                                     Delhi      2006921      25     1980379
# 9                                       Goa       259016      44      254959
#
#    Deaths  Active Ratio  Discharge Ratio  Death Ratio  Population
# ...

# %%
a.tail(10)
# Out:
#             State  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 26     Puducherry       175485       6      173504    1975          0.00
# 27         Punjab       784128      28      764811   19289          0.00
# 28      Rajasthan      1315207     106     1305448    9653          0.01
# 29         Sikkim        44314       3       43812     499          0.01
# 30     Tamil Nadu      3594062     293     3555720   38049          0.01
# 31      Telengana       841070      73      836886    4111          0.01
# 32        Tripura       108032       1      107091     940          0.00
# 33  Uttar Pradesh      2128020     140     2104248   23632          0.01
# 34    Uttarakhand       449284      36      441497    7751          0.01
# 35    West Bengal      2118451      84     2096836   21531          0.00
#
#     Discharge Ratio  Death Ratio  Population
# 26            98.87         1.13     2073074
# 27            97.54         2.46    34698876
# ...

# %% [markdown]
# # Maximum deaths populations

# %%
a[a.Deaths==np.max(a.Deaths)].Population
# Out:
# 20    399001
# Name: Population, dtype: int64

# %% [markdown]
# # State punjab Deaths

# %%
a[a.State=='Punjab'].Deaths
# Out:
# 27    19289
# Name: Deaths, dtype: int64

# %% [markdown]
# # greater than 500 Active with bar chart

# %%
a[a.Active>500].State.value_counts().plot(kind='bar',cmap='cool')
# Out:
# <AxesSubplot:>

# %%
a
# Out:
#                                        State  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10741       0       10612
# 1                             Andhra Pradesh      2339048       9     2324306
# 2                          Arunachal Pradesh        66887       1       66590
# 3                                      Assam       746099       0      738064
# 4                                      Bihar       851339      18      839019
# 5                                 Chandigarh        99335       7       98147
# 6                               Chhattisgarh      1177724      14     1163565
# 7   Dadra and Nagar Haveli and Daman and Diu        11591       1       11586
# 8                                      Delhi      2006921      25     1980379
# 9                                        Goa       259016      44      254959
# 10                                   Gujarat      1277422     221     1266158
# ...

# %%
import matplotlib.pyplot as plt

a.plot(kind='bar',cmap='cool')
plt.grid()

# %%
a.sort_values(by='Deaths',ascending=False).value_counts().plot(kind='bar',cmap='cool')
plt.show()
