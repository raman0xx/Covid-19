# %% [markdown]
# # Exploratory Data Analysis on E-Commerce Data Project Work:-

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset/data.csv',encoding='cp1252')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # 1. How to find out total no. of records

# %%
df.shape[0]
# Out:
# 541909

# %% [markdown]
# #  2. How to find out total no. of columns?

# %%
df.shape[1]
# Out:
# 8

# %% [markdown]
# # 3. Display all column names ?

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# # 4. All Column Names Description:-

# %% [markdown]
# # # InvoiceNo (invoice_num): A number assigned to each transaction

# %%
df.InvoiceNo
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
# Name: InvoiceNo, Length: 541909, dtype: object

# %% [markdown]
# #  StockCode (stock_code): Product code

# %%
df.StockCode
# Out:
# 0         85123A
# 1          71053
# 2         84406B
# 3         84029G
# 4         84029E
#            ...
# 541904     22613
# 541905     22899
# 541906     23254
# 541907     23255
# 541908     22138
# Name: StockCode, Length: 541909, dtype: object

# %% [markdown]
# # # Description (description): Product name

# %%
df.Description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %% [markdown]
# # # Quantity (quantity): Number of products purchased for each transaction

# %%
df.Quantity
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: Quantity, Length: 541909, dtype: int64

# %% [markdown]
# # # InvoiceDate (invoice_date): Timestamp for each transaction

# %%
df.InvoiceDate
# Out:
# 0          12/1/2010 8:26
# 1          12/1/2010 8:26
# 2          12/1/2010 8:26
# 3          12/1/2010 8:26
# 4          12/1/2010 8:26
#                ...
# 541904    12/9/2011 12:50
# 541905    12/9/2011 12:50
# 541906    12/9/2011 12:50
# 541907    12/9/2011 12:50
# 541908    12/9/2011 12:50
# Name: InvoiceDate, Length: 541909, dtype: object

# %% [markdown]
# # # UnitPrice (unit_price): Product price per unit

# %%
df.UnitPrice
# Out:
# 0         2.55
# 1         3.39
# 2         2.75
# 3         3.39
# 4         3.39
#           ...
# 541904    0.85
# 541905    2.10
# 541906    4.15
# 541907    4.15
# 541908    4.95
# Name: UnitPrice, Length: 541909, dtype: float64

# %% [markdown]
# # CustomerId

# %%
df.CustomerID
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 541909, dtype: float64

# %% [markdown]
# # Country names

# %%
df.Country
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541904            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 541909, dtype: object

# %% [markdown]
# # 5 How to find all missing value for each column?

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %% [markdown]
# # 6 First show all Quantity has negative value records?

# %%
df[df.Quantity<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # 7 Then find out total shape of quantity has negative value records?[shape=10624]

# %%
b=df[df.Quantity<0].shape[0]
b
# Out:
# 10624

# %% [markdown]
# # 8 How to remove all quantity records with negative values?

# %%
df_new=df[~(df['Quantity']<0)]
df_new
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # 9 Then find out total records shape?[df_new.shape is 541909-10624=531285]

# %%
df_new=df[~(df['Quantity']<0)]
df_new.shape
# Out:
# (531285, 8)

# %% [markdown]
# # # amount_spent = quantity * unit_price

# %%
df['Amount_Spent']=df.Quantity*df.UnitPrice

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  Year  Month  Day  Hour  UnitPrice  CustomerID  \
# ...

# %% [markdown]
# # # To calculate the total money spent on each purchase,

# %%
df.UnitPrice.sum()
# Out:
# 2498803.974

# %% [markdown]
# # 10. After UnitPrice column insert new column Amount_Spent & also formula assigned?

# %%
df.insert(6,'Amount_price',AMount_price

# %% [markdown]
# # 11. InvoiceDate column converts string format into datetime format?

# %%
df['InvoiceDate']=pd.to_datetime(df.InvoiceDate)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.dtypes
# Out:
# InvoiceNo               object
# StockCode               object
# Description             object
# Quantity                 int64
# InvoiceDate     datetime64[ns]
# UnitPrice              float64
# CustomerID             float64
# Country                 object
# Amount_Spent           float64
# dtype: object

# %% [markdown]
# # 12.  We add a few columns after InvoiceDate that consist of the Year, Month, Day  and Hour for each transaction for analysis work.

# %%
df.insert(5,'Year',df.InvoiceDate.dt.year)        ###YEAR

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  Year  UnitPrice  CustomerID         Country  \
# ...

# %%
df.insert(6,'Month',df.InvoiceDate.dt.month)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  Year  Month  UnitPrice  CustomerID  \
# ...

# %%
df.insert(7,'Day',df.InvoiceDate.dt.day)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  Year  Month  Day  UnitPrice  CustomerID  \
# ...

# %%
df.insert(8,'Hour',df.InvoiceDate.dt.hour)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  Year  Month  Day  Hour  UnitPrice  CustomerID  \
# ...

# %% [markdown]
# # 13. How to find out Top 5 customers with highest money spent records?Show Only 3 columns ['CustomerID','Country','Amount_Spent']

# %%
index=df.sort_values(by='Amount_Spent',ascending=False).head().index.to_list()
df.loc[index,['CustomerID','Country','Amount_Spent']]
# Out:
#         CustomerID         Country  Amount_Spent
# 540421     16446.0  United Kingdom     168469.60
# 61619      12346.0  United Kingdom      77183.60
# 222680     15098.0  United Kingdom      38970.00
# 15017          NaN  United Kingdom      13541.33
# 299982         NaN  United Kingdom      11062.06

# %% [markdown]
# # 14. Plotting bar chart : How many orders (per month)?

# %%
plt.xlabel('Month')
plt.ylabel('Numbers of orders')
plt.title('Number of orders for different months')
df.Month.value_counts().plot(kind='bar',cmap='hot')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible=None, which='major', axis='both', **kwargs)>

# %% [markdown]
# # 15. Plotting bar chart : How many orders (per year)?

# %%
plt.xlabel('Year')
plt.ylabel('Number of Orders')
plt.title('Number of orders for different Year')
df.Year.value_counts().plot(kind='bar',cmap='cool')
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible=None, which='major', axis='both', **kwargs)>

# %% [markdown]
# # 16. Plotting bar chart : How many orders (per hour)?

# %%
plt.xlabel('Hour')
plt.ylabel('Number of orders')
plt.title('Number of orders for different hour')
df.Hour.value_counts().plot(kind='bar',cmap='pink')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
